# %%
import pandas as pd
import numpy as np

# %%
sub_saharan_Africa_economy_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Sub-Saharan Africa Economic Data/AFRREO_04-29-2022 19-12-45-09_timeSeries.csv')
sub_saharan_Africa_economy_df.head(2)
# Out:
#   Country Name  Country Code  \
# 0      Liberia           668
# 1      Lesotho           666
#
#                                       Indicator Name   Indicator Code  \
# 0  Gross Domestic Product, Real, Percent change, ...  NGDP_R_PC_PP_PT
# 1  Gross Domestic Product, Real, Percent change, ...  NGDP_R_PC_PP_PT
#
#   Attribute      2004      2005      2006       2007      2008  ...      2016  \
# 0     Value  3.971099  5.856214  8.480018  13.102969  6.105134  ... -1.630070
# 1     Value  2.397611  3.111950  4.417355   4.992812  3.759894  ...  1.884993
#
#        2017      2018      2019      2020      2021      2022      2023  \
# 0  2.468629  1.241918 -2.515768 -2.966884  4.217417  4.546422  5.518998
# 1 -2.704771 -0.279678  0.000286 -5.982275  2.111634  3.069779  1.593664
#
#    Base Year  Unnamed: 26
# 0        NaN          NaN
# 1        NaN          NaN
#
# [2 rows x 27 columns]

# %%
sub_saharan_Africa_economy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1653 entries, 0 to 1652
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    1653 non-null   object
#  1   Country Code    1653 non-null   int64
#  2   Indicator Name  1653 non-null   object
#  3   Indicator Code  1653 non-null   object
#  4   Attribute       1653 non-null   object
#  5   2004            1618 non-null   float64
#  6   2005            1628 non-null   float64
#  7   2006            1628 non-null   float64
#  8   2007            1628 non-null   float64
#  9   2008            1628 non-null   float64
#  10  2009            1629 non-null   float64
#  11  2010            1629 non-null   float64
#  12  2011            1645 non-null   float64
#  13  2012            1651 non-null   float64
#  14  2013            1651 non-null   float64
#  15  2014            1651 non-null   float64
#  16  2015            1652 non-null   float64
# ...

# %%
sub_saharan_Africa_economy_df.describe()
# Out:
#        Country Code         2004         2005         2006         2007  \
# count   1653.000000  1618.000000  1628.000000  1628.000000  1628.000000
# mean     674.232305    26.653102    25.749007    25.940379    25.064559
# std       76.902437    42.652977    39.590846    38.194888    36.145810
# min      199.000000   -64.072263   -73.769307   -39.028133   -72.729363
# 25%      638.000000     2.752470     3.504702     3.968726     3.646096
# 50%      676.000000    12.843496    12.700192    13.022966    13.250934
# 75%      718.000000    30.625592    30.892085    30.029867    30.196127
# max      776.000000   543.398738   488.458169   450.954848   366.805393
#
#               2008         2009         2010         2011         2012  ...  \
# count  1628.000000  1629.000000  1629.000000  1645.000000  1651.000000  ...
# mean     25.778014    23.439127    23.367415    23.655589    23.119919  ...
# std      35.539075    35.552129    32.899900    32.818714    32.987508  ...
# ...
